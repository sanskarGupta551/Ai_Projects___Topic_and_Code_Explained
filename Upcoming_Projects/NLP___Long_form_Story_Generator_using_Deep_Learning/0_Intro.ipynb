# %% [markdown]
# # **Long-Form Story Generator** `(0/3)`
#
# ### **Summary**
#
# *
#
# '''
#
# ### **Process**
#
# * [1. Build a Custom Dataset](#1)
# * [2. Train Model](#2)
# * [3. Prompter & Pipeline](#3)
# * [4. Inference](#4)
#
# ***
# ***

# %% [markdown]
# ## **1. Build a Custom Dataset**
#
# * `Filter` out `Stories` from `existing Datasets` to build this Dataset.
# * The `Dataset` will be made up of the following `Sub-sets` :-
#
# #### **a. Synopsis**
#
# * `Prefix` - Synopsis
# * `Inputs` - PROMPT containing following Inputs:
#     * **Prefix**(Synopsis),
#     * **Story Title**(from User Inputs),
#     * **Context**(from User Inputs),
#     * **Conflict**(from User Inputs),
#     * **Beginning**(from User Inputs),
#     * **Ending**(from User Inputs),
#     * **Literary**(Genre, Style, Tone, Mood, Theme - all from User Inputs),
#     * **Keywords**(from User Inputs)
# * `Output` - <200 WORDS Plot Synopsis
# * `Number of Sets` - 25,000
#
# #### **b. Begin**
#
# * `Prefix` - Begin
# * `Inputs` - PROMPT containing following Inputs:
#     * **Prefix**(Begin),
#     * **Story Title**(from User Inputs),
#     * **Context**(from User Inputs),
#     * **Conflict**(from User Inputs),
#     * **Synopsis**(Previously Generated by the same Model),
#     * **Beginning**(from User Inputs),
#     * **Literary**(Genre, Style, Tone, Mood, Theme - all from User Inputs),
#     * **Keywords**(from User Inputs)
# * `Output` - ~500 WORDS Beginning of the Story
# * `Number of Sets` - 25,000
#
# #### **c. Continue**
#
# * `Prefix` - Continue
# * `Inputs` - PROMPT containing following Inputs:
#     * **Prefix**(Continue),
#     * **Story Title**(from User Inputs),
#     * **Context**(from User Inputs),
#     * **Conflict**(from User Inputs),
#     * **Synopsis**(Previously Generated by the same Model),
#     * **Summary**(Extractive Summarization of past 1000 words)/ **Text Reference**(past 1000 words),
#     * **Literary**(Genre, Style, Tone, Mood, Theme - all from User Inputs),
#     * **Keywords**(from User Inputs),
#     * **Last Sentence**(from Story)
# * `Output` - ~500 WORDS Continuation of the Story
# * `Number of Sets` - 75,000
#
# #### **d. End**
#
# * `Prefix` - End
# * `Inputs` - PROMPT containing following Inputs:
#     * **Prefix**(End),
#     * **Story Title**(from User Inputs),
#     * **Context**(from User Inputs),
#     * **Conflict**(from User Inputs),
#     * **Synopsis**(Previously Generated by the same Model),
#     * **Summary**(Extractive Summarization of past 2000 words)/ **Text Reference**(past 1000 words),
#     * **Ending**(from User Inputs),
#     * **Literary**(Genre, Style, Tone, Mood, Theme - all from User Inputs),
#     * **Keywords**(from User Inputs),
#     * **Last Sentence**(from Story)
# * `Output` - ~500 WORDS Ending of the Story
# * `Number of Sets` - 25,000
#
# #### **e. Extractive Summarization**
#
# * `Prefix` - Extractive Summarization
# * `Inputs` - PROMPT containing following Inputs:
#     * **Prefix**(Extractive Summarization),
#     * **Text Reference**(~500 words)
# * `Output` - ~50 words Extractive Summary
# * `Number of Sets` - 50,000
#
# ***
# ***

# %%
"""

"""
